# %% [markdown]
# # Tugas 1

# %% [markdown]
# ## 1. Membaca data Dari URL

# %%
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import statistics as st
from scipy import stats

url="https://raw.githubusercontent.com/Ihsan210702/dataset/main/jumlah-kelurahan-yang-melaksanakan-sanitasi-total-berbasis-masyarakat-stbm-tahun-2019.csv"

c = pd.read_csv(url)

# %% [markdown]
# Menampilkan *dataset*

# %%
#menampilkan data
c
# Out:
#                                    wilayah  jumlah_target_denominator\n  \
# 0          Kota Administrasi Jakarta Pusat                           44
# 1          Kota Administrasi Jakarta Utara                           31
# 2          Kota Administrasi Jakarta Barat                           56
# 3        Kota Administrasi Jakarta Selatan                           65
# 4          Kota Administrasi Jakarta Timur                           65
# 5  Kabupaten Administrasi Kepulauan Seribu                            6
#
#    jumlah_capaian_numerator  realisasi_capaian
# 0                        44                 44
# 1                        23                 23
# 2                        56                 56
# 3                        65                 65
# 4                        61                 61
# 5                         5                  5

# %% [markdown]
# ## 2.   Membuat Statistik Deskriptif dari data (setiap atribut yang bertipe numerik)
#
#
# Statistik Deskriptif yang ada:
# * count - Jumlah nilai yang tidak kosong.
# * mean - Nilai rata-rata (rata-rata).
# * std - Standar deviasi.
# * min - nilai minimum.
# * 25% - Persentil 25%*.
# * 50% - Persentil 50%*.
# * 75% - Persentil 75%*.
# * maks - nilai maksimum.
# * median - nilai tengah.

# %%
#menampilkan informasi dari kolom data numerik 
c.describe()
# Out:
#        jumlah_target_denominator\n  jumlah_capaian_numerator  \
# count                     6.000000                  6.000000
# mean                     44.500000                 42.333333
# std                      22.967368                 23.745877
# min                       6.000000                  5.000000
# 25%                      34.250000                 28.250000
# 50%                      50.000000                 50.000000
# 75%                      62.750000                 59.750000
# max                      65.000000                 65.000000
#
#        realisasi_capaian
# count           6.000000
# mean           42.333333
# std            23.745877
# min             5.000000
# 25%            28.250000
# 50%            50.000000
# 75%            59.750000
# max            65.000000

# %% [markdown]
# **Rumus Mean**
#
# Dalam statistika dan matematika, mean disebut juga dengan rata-rata. Jadi, definisi mean adalah nilai rata-rata dari sekumpulan data yang terdiri dari dua atau lebih..
# Berikut rumus mean untuk data tunggal:
# $$\bar{x}=\frac{\sum x_i}{n}
# $$
# Keterangan:
#
# $\bar{x}:$ nilai rata-rata
#
# $\mathrm{x}_{\mathrm{i}}$ : nilai data ke-i
#
# n : banyaknya data

# %%
mean = {'jumlah_target_denominator\n':np.mean(c['jumlah_target_denominator\n']),
		'jumlah_capaian_numerator': np.mean(c['jumlah_capaian_numerator']),'realisasi_capaian':np.mean(c['realisasi_capaian'])
    }

df = pd.DataFrame(mean, index=['mean'])
df
# Out:
#       jumlah_target_denominator\n  jumlah_capaian_numerator  realisasi_capaian
# mean                         44.5                 42.333333          42.333333

# %% [markdown]
# **Rumus Median**
#
# Median disebut juga dengan nilai tengah. Median diperoleh dengan cara mengambil nilai tengah pada data yang telah disusun secara berurutan dari angka terkecil ke terbesar.
# Pada data tunggal untuk menentukan median yaitu:
# Misalkan banyaknya data n,
#
# Untuk $n$ ganjil: $M e=x_{\frac{1}{2}(n+1)}$
#
# Untuk $n$ genap: $M e=\frac{\frac{x_n}{2}+\frac{x_n}{2}+1}{2}$
#
# Keterangan:
# $x_{\frac{n}{2}}=$ data pada urutan ke- $\frac{n}{2}$ setelah diurutkan.

# %%
median = {'jumlah_target_denominator\n':np.median(c['jumlah_target_denominator\n']),
		'jumlah_capaian_numerator': np.median(c['jumlah_capaian_numerator']),'realisasi_capaian':np.median(c['realisasi_capaian'])
    }

df = pd.DataFrame(median, index=['median'])
df
# Out:
#         jumlah_target_denominator\n  jumlah_capaian_numerator  \
# median                         50.0                      50.0
#
#         realisasi_capaian
# median               50.0

# %% [markdown]
# **Modus**
#
# Modus adalah nilai data yang paling sering muncul atau nilai data yang frekuensinya paling besar.

# %%
modus = {'jumlah_target_denominator\n':stats.mode(c['jumlah_target_denominator\n']),
		'jumlah_capaian_numerator': stats.mode(c['jumlah_capaian_numerator']),'realisasi_capaian':stats.mode(c['realisasi_capaian'])
    }

modus
# Out:
# {'jumlah_target_denominator\n': ModeResult(mode=array([65]), count=array([2])),
#  'jumlah_capaian_numerator': ModeResult(mode=array([5]), count=array([1])),
#  'realisasi_capaian': ModeResult(mode=array([5]), count=array([1]))}

# %% [markdown]
# **Rumus Standar Deviasi**
#
# Standar deviasi atau simpangan baku biasanya diajarkan pada ilmu statistik untuk mengukur tingkat kesamaan atau kedekatan dalam suatu kelompok.
#
# Standar deviasi adalah nilai statistik yang sering kali dipakai dalam menentukan kedekatan sebaran data yang ada di dalam sampel dan seberapa dekat titik data individu dengan mean atau rata-rata nilai dari sampel itu sendiri.
#
# Untuk Data Tunggal :
# $S=\sqrt{\frac{\sum\left(x_i-\bar{x}\right)^2}{n}}$
#
# $S=$ Standar deviasi
#
# $x_i=$ nilai $\mathrm{x} \mathrm {ke-i}$
#
# $\bar{x}=$ nilai rata-rata data
#
# $n=$ jumlah data

# %%
std = {'jumlah_target_denominator\n':st.stdev(c['jumlah_target_denominator\n']),
		'jumlah_capaian_numerator':st.stdev(c['jumlah_capaian_numerator']),'realisasi_capaian':st.stdev(c['realisasi_capaian'])}

df = pd.DataFrame(std, index=['std'])
df
# Out:
#      jumlah_target_denominator\n  jumlah_capaian_numerator  realisasi_capaian
# std                    22.967368                 23.745877          23.745877

# %% [markdown]
# **Nilai Minimum**
#
# Dilakukan dengan mengurutkan semua data dari yang terkecil ke terbesar,
# Kemudian diambil nilai yang terkecil

# %%
min = {'jumlah_target_denominator\n':np.min(c['jumlah_target_denominator\n']),
		'jumlah_capaian_numerator': np.min(c['jumlah_capaian_numerator']),'realisasi_capaian':np.min(c['realisasi_capaian'])
    }

df = pd.DataFrame(min, index=['min'])
df
# Out:
#      jumlah_target_denominator\n  jumlah_capaian_numerator  realisasi_capaian
# min                            6                         5                  5

# %% [markdown]
# RUMUS PERSENTIL DATA TUNGGAL
# $$
# P_i=\text { data } k e-\frac{i(n+1)}{100}
# $$
#
# Jika persentil 25% maka:
# $$
# P_i=\text { data } k e-\frac{25(n+1)}{100}
# $$
#
# Jika persentil 50% maka:
# $$
# P_i=\text { data } k e-\frac{50(n+1)}{100}
# $$
#
# Jika persentil 75% maka:
# $$
# P_i=\text { data } k e-\frac{75(n+1)}{100}
# $$
#
# Keterangan:
#
# $\mathrm{P}=$ persentil ke $-\mathrm{i}$
#
# $$
# i=1,2,3, \ldots, 99
# $$
# n = banyak data

# %%
percentile25 = {'jumlah_target_denominator\n':np.percentile(c['jumlah_target_denominator\n'],25),
		'jumlah_capaian_numerator':np.percentile(c['jumlah_capaian_numerator'],25),'realisasi_capaian':np.percentile(c['realisasi_capaian'],25)
    }

df = pd.DataFrame(percentile25, index=['25%'])
df
# Out:
#      jumlah_target_denominator\n  jumlah_capaian_numerator  realisasi_capaian
# 25%                        34.25                     28.25              28.25

# %%
percentile50 = {'jumlah_target_denominator\n':np.percentile(c['jumlah_target_denominator\n'],50),
		'jumlah_capaian_numerator':np.percentile(c['jumlah_capaian_numerator'],50),'realisasi_capaian':np.percentile(c['realisasi_capaian'],50)
    }

df = pd.DataFrame(percentile50, index=['50%'])
df
# Out:
#      jumlah_target_denominator\n  jumlah_capaian_numerator  realisasi_capaian
# 50%                         50.0                      50.0               50.0

# %%
percentile75 = {'jumlah_target_denominator\n':np.percentile(c['jumlah_target_denominator\n'],75),
		'jumlah_capaian_numerator':np.percentile(c['jumlah_capaian_numerator'],75),'realisasi_capaian':np.percentile(c['realisasi_capaian'],75)
    }

df = pd.DataFrame(percentile75, index=['75%'])
df
# Out:
#      jumlah_target_denominator\n  jumlah_capaian_numerator  realisasi_capaian
# 75%                        62.75                     59.75              59.75

# %% [markdown]
# **Nilai Maksimum**
#
# Dilakukan dengan mengurutkan semua data dari yang terkecil ke terbesar,
# Kemudian diambil nilai yang terbesar

# %%
max = {'jumlah_target_denominator\n':np.max(c['jumlah_target_denominator\n']),
		'jumlah_capaian_numerator': np.max(c['jumlah_capaian_numerator']),'realisasi_capaian':np.max(c['realisasi_capaian'])
    }

df = pd.DataFrame(max, index=['max'])
df
# Out:
#      jumlah_target_denominator\n  jumlah_capaian_numerator  realisasi_capaian
# max                           65                        65                 65

# %% [markdown]
# ## 3.   Mendeskripsikan kemiringan/skewned dari data setiap variabel(bertipe numerik)

# %% [markdown]
# *Kemencengan atau kecondongan (skewness)* adalah tingkat ketidaksimetrisan atau kejauhan simetri dari sebuah distribusi. Skewness diartikan sebagai kemiringan distribusi data. Sebuah distribusi yang tidak simetris akan memiliki rata-rata, median, dan modus yang tidak sama besarnya sehingga distribusi akan terkonsentrasi pada salah satu sisi dan kurvanya akan menceng. Ukuran kemiringan kurva adalah derajat atau ukuran dari ketidaksimetrian suatu distribusi data.

# %%
sns.distplot(c['jumlah_target_denominator\n'],kde=True,
             bins= int(150/5),color='lightgreen',
             hist_kws={'edgecolor':'black'},
             kde_kws={'linewidth':4})
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(c['jumlah_capaian_numerator'],kde=True,
             bins= int(150/5),color='red',
             hist_kws={'edgecolor':'black'},
             kde_kws={'linewidth':4})
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(c['realisasi_capaian'],kde=True,
             bins= int(150/5),color='black',
             hist_kws={'edgecolor':'black'},
             kde_kws={'linewidth':4})
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
